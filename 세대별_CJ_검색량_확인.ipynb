# %% [markdown]
# <a href="https://colab.research.google.com/github/pennya6/CJ_project/blob/main/%EC%84%B8%EB%8C%80%EB%B3%84_CJ_%EA%B2%80%EC%83%89%EB%9F%89_%ED%99%95%EC%9D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
client_id="l54OU3RyAxGlGgRaggwl"
client_secret="rMEF6wnAEF"

# %%
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2021-03-01\",\"endDate\":\"2021-06-30\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"CJ택배 배송조회\",\"keywords\":[\"CJ택배 배송조회\"]}],\"ages\":[\"1\",\"2\",\"3\",\"4\"]}";

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    output_data=response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)

# %%
result=json.loads(output_data)

# %%
date = [a['period'] for a in result['results'][0]['data']]

ratio = [a['ratio'] for a in result['results'][0]['data']]

new=pd.DataFrame({'date':date, 
              'output':ratio})

# %%
 body2 = "{\"startDate\":\"2021-03-01\",\"endDate\":\"2021-06-30\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"CJ\",\"keywords\":[\"CJ\"]}],\"ages\":[\"5\",\"6\",\"7\",\"8\",\"9\",\"10\"]}";
 body3 = "{\"startDate\":\"2021-03-01\",\"endDate\":\"2021-06-30\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"CJ\",\"keywords\":[\"CJ\"]}],\"ages\":[\"11\"]}";

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body2.encode("utf-8"))
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    output_data2=response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)

# %%
result2=json.loads(output_data2)

# %%
date2 = [a['period'] for a in result2['results'][0]['data']]

ratio2 = [a['ratio'] for a in result2['results'][0]['data']]

new2=pd.DataFrame({'date':date2, 
              'output':ratio2})

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body3.encode("utf-8"))
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    output_data3=response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)

# %%
result3=json.loads(output_data3)
date3 = [a['period'] for a in result3['results'][0]['data']]

ratio3 = [a['ratio'] for a in result3['results'][0]['data']]

new3=pd.DataFrame({'date':date3, 
              'output':ratio3})

# %%
plt.plot(new.index,new['output'],label='10+20')
plt.plot(new2.index,new2['output'],label='30+40+50')
plt.plot(new3.index,new3['output'],label='60+70+80')
plt.legend()
plt.show()
